# %% [markdown]
# Checking out 311 data

# %%
import pandas as pd
import requests
from datetime import datetime
import random
from random import sample
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = "311_Service_Requests_from_2010_to_Present.csv"
n = sum(1 for line in open(file)) - 1 #loop: total number of records in the file (excluding header)
s = 100000 #desired sample size
skip = sorted(random.sample(range(1, n + 1), n - s)) #not including header, yields sorted random rows to be skipped
df = pd.read_csv(filename, skiprows=skip) #reads csv, skips random "undesired" rows leaving random desire number of rows
# Out:
# /Users/LJ/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (8,17,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
n # number or rows in file
# Out:
# 23096435

# %%
df.to_csv('311 Sample.csv') #save particular sample as 'workable' csv

# %%
df.describe()
# Out:
#          Unique Key           BBL  X Coordinate (State Plane)  \
# count  1.000000e+05  7.501600e+04                9.111200e+04
# mean   3.165476e+07  2.754084e+09                1.005159e+06
# std    8.395721e+06  1.166698e+09                2.253673e+04
# min    1.563353e+07  0.000000e+00                9.133570e+05
# 25%    2.477964e+07  2.028310e+09                9.932635e+05
# 50%    3.189475e+07  3.019640e+09                1.004395e+06
# 75%    3.876906e+07  4.007960e+09                1.017837e+06
# max    4.654852e+07  5.080500e+09                1.067060e+06
#
#        Y Coordinate (State Plane)      Latitude     Longitude
# count                91112.000000  91112.000000  91112.000000
# mean                205259.443674     40.730012    -73.924521
# std                  31570.351191      0.086654      0.081274
# min                 121462.000000     40.499811    -74.254937
# 25%                 182150.000000     40.666555    -73.967501
# ...

# %%
df.info() #check size of sample, non-null values and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      100000 non-null  int64
#  1   Created Date                    100000 non-null  object
#  2   Closed Date                     97300 non-null   object
#  3   Agency                          100000 non-null  object
#  4   Agency Name                     100000 non-null  object
#  5   Complaint Type                  100000 non-null  object
#  6   Descriptor                      98713 non-null   object
#  7   Location Type                   75137 non-null   object
#  8   Incident Zip                    94288 non-null   object
#  9   Incident Address                81528 non-null   object
#  10  Street Name                     81522 non-null   object
#  11  Cross Street 1                  67085 non-null   object
# ...

# %%
df['date convert'] = pd.to_datetime(df['Created Date']) #create "dummy" col to convert date

# %%
df['date convert'].dt.year.value_counts().sort_index() #check that sample is random and representative of original file
# Out:
# 2010     8775
# 2011     8493
# 2012     7769
# 2013     8003
# 2014     9090
# 2015    10059
# 2016    10548
# 2017    10783
# 2018    11980
# 2019    10396
# 2020     4104
# Name: Created Date, dtype: int64

# %%
df['Created Date'] = pd.to_datetime(df['Created Date']) #change col from obj type to datetime type
df['Closed Date'] = pd.to_datetime(df['Closed Date'])  #change col from obj type to datetime type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                
# 1        41923874 2019-03-10 11:40:24 2019-03-10 11:58:03   NYPD
# 2        41924382 2019-03-10 09:41:32 2019-03-10 13:31:54   NYPD
# 3        41924441 2019-03-10 11:21:15 2019-03-11 11:33:58    DCA
# 4        41925545 2019-03-12 00:32:22 2019-03-12 02:03:41   NYPD
# ...           ...                 ...                 ...    ...
# 99995    41920583 2019-03-10 18:25:26 2019-03-10 19:44:28   NYPD
# 99996    41920646 2019-03-10 13:43:22 2019-03-10 14:15:34   NYPD
# 99997    41920681 2019-03-10 22:57:41 2019-03-11 05:58:41   NYPD
# 99998    41921430 2019-03-10 20:00:24 2019-03-10 20:40:09   NYPD
# 99999    41922211 2019-03-11 00:09:38 2019-03-11 01:43:31   NYPD
#
#                            Agency Name       Complaint Type  \
# 0      New York City Police Department     Derelict Vehicle
# 1      New York City Police Department      Illegal Parking
# ...

# %%
df['Closed Date'][0] - df['Created Date'][0]  #time it took to close request with key 41922719 = 1 hr, 51 min, 18 secs
# Out:
# Timedelta('0 days 01:51:18')

# %%
df.sort_values(by=['Created Date'])
#df.to_csv('311 Sample.csv') -- resave sample as sorted version
# Out:
#        Unique Key        Created Date         Closed Date Agency  \
# 6903     15635382 2010-01-01 00:00:00 2010-01-07 00:00:00    HPD
# 6905     15635817 2010-01-01 00:00:00 2010-01-23 00:00:00    HPD
# 6904     15635708 2010-01-01 00:00:00 2010-02-11 00:00:00    HPD
# 6902     15635202 2010-01-01 00:00:00 2010-01-08 00:00:00    HPD
# 6901     15634942 2010-01-01 00:00:00 2010-01-06 00:00:00    HPD
# ...           ...                 ...                 ...    ...
# 90571    46543447 2020-06-20 00:51:58                 NaT   NYPD
# 90569    46538041 2020-06-20 01:28:43 2020-06-20 01:45:08   NYPD
# 90600    46547861 2020-06-20 01:38:16                 NaT   NYPD
# 90567    46540363 2020-06-20 01:46:35 2020-06-20 01:51:33   NYPD
# 90547    46534954 2020-06-20 01:51:54                 NaT   NYPD
#
#                                              Agency Name  \
# 6903   Department of Housing Preservation and Develop...
# 6905   Department of Housing Preservation and Develop...
# ...

# %%
complaints = df['Complaint Type'].value_counts()
complaints.head()
# Out:
# Noise - Residential    8497
# HEAT/HOT WATER         5683
# Street Condition       4272
# Illegal Parking        4255
# Blocked Driveway       4227
# Name: Complaint Type, dtype: int64

# %%
complaints.head(25).sort_values().plot(kind = 'bar')
#plt.xticks(rotation=70)
plt.figure(figsize=(50,50))
plt.show()

# %%
complaints = df['Complaint Type'].value_counts()

# %% [markdown]
# save sample as separate csv
# do model for date close-date open
